# %% [markdown]
# # Clean movies metadata

# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
import ast


from lib.types.dataset_type import DatasetType
from lib.types.source_type import SourceType

source: SourceType = SourceType.original

# %%
df = pd.read_csv(DatasetType.movies_metadata.path(source))
df['id'] = df['id'].astype(str)
df.head(1)
# Out:
# /Users/theachoem/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,2,5,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#    release_date      revenue runtime  \
# 0    1995-10-30  373554033.0    81.0
#
#                            spoken_languages    status  tagline      title  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released      NaN  Toy Story
#
#    video vote_average vote_count
# 0  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %%
df.shape
# Out:
# (45465, 24)

# %%
df.columns.tolist()
# Out:
# ['adult',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count']

# %% [markdown]
# ## 2. Extract genres and belongs to collection

# %%
def apply_genre(row: pd.Series):
    genres = row['genres']

    parsed_json = ast.literal_eval(genres)

    genre_ids = "|".join(([str(i['id']) for i in parsed_json]))
    genre_names = "|".join(([i['name'] for i in parsed_json]))

    row['genre_ids'] = genre_ids
    row['genre_names'] = genre_names

    # fillna popularity with 0.0
    popularity = row['popularity']
    if(str(popularity) == 'nan'):
        row['popularity'] = 0.0

    btc: str = row['belongs_to_collection']
    if (btc != None):
        try:
            parsed_json_btc = ast.literal_eval(btc)
            btc_id = parsed_json_btc['id']
            btc_name = parsed_json_btc['name']
            row['btc_name'] = btc_name
            row['btc_id'] = str(btc_id)
        except:
            row['btc_name'] = None
            row['btc_id'] = None

    return row


cleaned_df = df.apply(lambda row: apply_genre(row), axis=1)
cleaned_df.drop(
    labels=[
        'adult',
        'belongs_to_collection',
        'budget',
        'genres',
        'homepage',
        # 'id',
        'imdb_id',
        'original_language',
        'original_title',
        'overview',
        # 'popularity',
        'poster_path',
        'production_companies',
        'production_countries',
        'release_date',
        # 'revenue',
        'runtime',
        'spoken_languages',
        'status',
        'tagline',
        # 'title',
        'video',
        # 'vote_average',
        # 'vote_count',
    ],
    axis=1,
    inplace=True
)

# %% [markdown]
# ## 3. Find average rating

# %%
rating_df = pd.read_csv(DatasetType.ratings.path(source))
rating_df.rename(columns={'userId': 'user_id', 'movieId': 'id'}, inplace=True)

avg_rating_df: pd.DataFrame = rating_df.groupby('id').agg(
    avg_rating=('rating', 'mean'),
    quantity=('user_id', 'count')
).reset_index()

avg_rating_df['id'] = avg_rating_df['id'].astype(str)
avg_rating_df['quantity'] = avg_rating_df['id'].astype(str)
avg_rating_df
# Out:
#            id  avg_rating quantity
# 0           1    3.888157        1
# 1           2    3.236953        2
# 2           3    3.175550        3
# 3           4    2.875713        4
# 4           5    3.079565        5
# ...       ...         ...      ...
# 45110  176267    4.000000   176267
# 45111  176269    3.500000   176269
# 45112  176271    5.000000   176271
# 45113  176273    1.000000   176273
# 45114  176275    3.000000   176275
#
# [45115 rows x 3 columns]

# %% [markdown]
# ## 4. Merge avg_rating_df with clean_df

# %%
avg_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45115 entries, 0 to 45114
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          45115 non-null  object
#  1   avg_rating  45115 non-null  float64
#  2   quantity    45115 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 1.0+ MB

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45465 entries, 0 to 45464
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            45465 non-null  object
#  1   popularity    45465 non-null  float64
#  2   revenue       45461 non-null  float64
#  3   title         45461 non-null  object
#  4   vote_average  45461 non-null  float64
#  5   vote_count    45461 non-null  float64
#  6   genre_ids     45465 non-null  object
#  7   genre_names   45465 non-null  object
#  8   btc_name      4491 non-null   object
#  9   btc_id        4491 non-null   object
# dtypes: float64(4), object(6)
# memory usage: 3.5+ MB

# %%
movie_df_cleaned = pd.merge(
    left=cleaned_df,
    right=avg_rating_df,
    on='id',
    how='left'
)
movie_df_cleaned
# Out:
#            id  popularity      revenue                        title  \
# 0         862   21.946943  373554033.0                    Toy Story
# 1        8844   17.015539  262797249.0                      Jumanji
# 2       15602   11.712900          0.0             Grumpier Old Men
# 3       31357    3.859495   81452156.0            Waiting to Exhale
# 4       11862    8.387519   76578911.0  Father of the Bride Part II
# ...       ...         ...          ...                          ...
# 45460  439050    0.072051          0.0                       Subdue
# 45461  111109    0.178241          0.0          Century of Birthing
# 45462   67758    0.903007          0.0                     Betrayal
# 45463  227506    0.003503          0.0             Satan Triumphant
# 45464  461257    0.163015          0.0                     Queerama
#
#        vote_average  vote_count    genre_ids               genre_names  \
# 0               7.7      5415.0  16|35|10751   Animation|Comedy|Family
# 1               6.9      2413.0  12|14|10751  Adventure|Fantasy|Family
# 2               6.5        92.0     10749|35            Romance|Comedy
# 3               6.1        34.0  35|18|10749      Comedy|Drama|Romance
# 4               5.7       173.0           35                    Comedy
# ...             ...         ...          ...                       ...
# 45460           4.0         1.0     18|10751              Drama|Family
# 45461           9.0         3.0           18                     Drama
# 45462           3.8         6.0     28|18|53     Action|Drama|Thriller
# 45463           0.0         0.0
# 45464           0.0         0.0
#
#                              btc_name  btc_id  avg_rating quantity
# 0                Toy Story Collection   10194    3.598930      862
# 1                                None    None    3.760163     8844
# 2           Grumpy Old Men Collection  119050         NaN      NaN
# 3                                None    None         NaN      NaN
# 4      Father of the Bride Collection   96871         NaN      NaN
# ...                               ...     ...         ...      ...
# 45460                            None    None         NaN      NaN
# 45461                            None    None    2.583333   111109
# 45462                            None    None         NaN      NaN
# 45463                            None    None         NaN      NaN
# 45464                            None    None         NaN      NaN
#
# [45465 rows x 12 columns]

# %%
# bug_df = movie_df_cleaned[movie_df_cleaned['popularity'].map(lambda x: isinstance(x, str))]
# bug_df

# %%
# movie_df_cleaned.loc['popularity'] = movie_df_cleaned['popularity'].astype(float)
# movie_df_cleaned

import numpy as np

# movie_df_cleaned['popularity'] = movie_df_cleaned['popularity'].replace(np.nan, 0)
# movie_df_cleaned['popularity'].fillna("nan", inplace=True)

movie_df_cleaned['popularity'] = movie_df_cleaned['popularity'].astype(float)
movie_df_cleaned['revenue'] = movie_df_cleaned['revenue'].astype(float)

movie_df_cleaned['avg_rating'].fillna(0, inplace=True)
movie_df_cleaned['quantity'].fillna(0, inplace=True)

movie_df_cleaned
# Out:
#            id  popularity      revenue                        title  \
# 0         862   21.946943  373554033.0                    Toy Story
# 1        8844   17.015539  262797249.0                      Jumanji
# 2       15602   11.712900          0.0             Grumpier Old Men
# 3       31357    3.859495   81452156.0            Waiting to Exhale
# 4       11862    8.387519   76578911.0  Father of the Bride Part II
# ...       ...         ...          ...                          ...
# 45460  439050    0.072051          0.0                       Subdue
# 45461  111109    0.178241          0.0          Century of Birthing
# 45462   67758    0.903007          0.0                     Betrayal
# 45463  227506    0.003503          0.0             Satan Triumphant
# 45464  461257    0.163015          0.0                     Queerama
#
#        vote_average  vote_count    genre_ids               genre_names  \
# 0               7.7      5415.0  16|35|10751   Animation|Comedy|Family
# 1               6.9      2413.0  12|14|10751  Adventure|Fantasy|Family
# 2               6.5        92.0     10749|35            Romance|Comedy
# 3               6.1        34.0  35|18|10749      Comedy|Drama|Romance
# 4               5.7       173.0           35                    Comedy
# ...             ...         ...          ...                       ...
# 45460           4.0         1.0     18|10751              Drama|Family
# 45461           9.0         3.0           18                     Drama
# 45462           3.8         6.0     28|18|53     Action|Drama|Thriller
# 45463           0.0         0.0
# 45464           0.0         0.0
#
#                              btc_name  btc_id  avg_rating  quantity
# 0                Toy Story Collection   10194    3.598930       862
# 1                                None    None    3.760163      8844
# 2           Grumpy Old Men Collection  119050    0.000000         0
# 3                                None    None    0.000000         0
# 4      Father of the Bride Collection   96871    0.000000         0
# ...                               ...     ...         ...       ...
# 45460                            None    None    0.000000         0
# 45461                            None    None    2.583333    111109
# 45462                            None    None    0.000000         0
# 45463                            None    None    0.000000         0
# 45464                            None    None    0.000000         0
#
# [45465 rows x 12 columns]

# %% [markdown]
# ## 5. Write to CSV

# %%
from lib.utils.utils import write_csv

write_csv(DatasetType.movies_metadata.cleaned_path(), movie_df_cleaned)
