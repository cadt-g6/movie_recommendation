# %% [markdown]
# # Related Movies Recommendation
#
# ## I. Setup

# %%
import sys
sys.path.append('..')

# %%
from lib.types.dataset_type import DatasetType
import pandas as pd

# %%
metadata_df = pd.read_csv(DatasetType.movies_metadata.original_path())
metadata_df.sample(10)
# Out:
# /var/folders/g8/wgj905m158gbcnzm6q5v9y2r0000gn/T/ipykernel_19901/597785676.py:1: DtypeWarning: Columns (0,2,5,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DatasetType.movies_metadata.original_path())
#        adult                              belongs_to_collection budget  \
# 33981  False                                                NaN      0
# 14572  False  {'id': 298820, 'name': 'American Pie (Spin-off...      0
# 39804  False                                                NaN      0
# 28016  False                                                NaN      0
# 14249  False                                                NaN    450
# 9443   False                                                NaN      0
# 13712  False                                                NaN      0
# 25202  False                                                NaN      0
# 32447  False                                                NaN      0
# 6820   False                                                NaN      0
#
#                                                   genres homepage      id  \
# 33981                   [{'id': 53, 'name': 'Thriller'}]      NaN   35724
# 14572                     [{'id': 35, 'name': 'Comedy'}]      NaN   26123
# 39804           [{'id': 878, 'name': 'Science Fiction'}]      NaN   94502
# 28016                      [{'id': 18, 'name': 'Drama'}]      NaN  289278
# 14249  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...      NaN   63795
# 9443   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   37209
# 13712  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...      NaN   36460
# 25202  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN  204965
# 32447  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...      NaN   60850
# 6820                       [{'id': 18, 'name': 'Drama'}]      NaN   44479
#
#          imdb_id original_language                           original_title  \
# 33981  tt0499484                en                          The Genius Club
# 14572  tt1407050                en  American Pie Presents: The Book of Love
# 39804  tt0090068                en                                 Starship
# 28016  tt2923652                sv                     Min så kallade pappa
# 14249  tt0044320                en    Abbott and Costello Meet Captain Kidd
# 9443   tt0366996                en           The Saddest Music in the World
# 13712  tt0081110                en               The Man With Bogart's Face
# 25202  tt2499818                de                             Drei Stunden
# 32447  tt0838192                de                     Reine Geschmacksache
# 6820   tt0118125                en                     The Watermelon Woman
#
#                                                 overview  ...  release_date  \
# 33981  Seven geniuses, with IQs over 200, are plucked...  ...    2006-01-01
# 14572  Ten years after the first American Pie movie, ...  ...    2009-06-18
# 39804  Jowitt, a mercenary without recluse institutes...  ...    1984-12-13
# 28016  A daughter helps her estranged father who's lo...  ...    2014-09-19
# 14249  Two hapless waiters in a tavern on the Spanish...  ...    1952-12-27
# 9443   In Depression-era Winnipeg, a legless beer bar...  ...    2003-09-17
# 13712  In The Man With Bogart's Face, an affectionate...  ...    1980-10-03
# 25202                                                NaN  ...    2013-07-24
# 32447  At 52, traveling salesman Wolfgang Zenker (Edg...  ...    2007-08-08
# 6820   Cheryl, a young black lesbian, works a day job...  ...    1996-09-07
#
#          revenue runtime                          spoken_languages    status  \
# 33981        0.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14572        0.0    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 39804        0.0    95.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 28016        0.0   123.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 14249        0.0    70.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9443         0.0   100.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 13712        0.0   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 25202        0.0     NaN  [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released
# 32447  1101480.0   105.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released
# 6820         0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 33981                                          Solve it.
# 14572                                                NaN
# 39804                                                NaN
# 28016                                                NaN
# 14249            It's one big roar, from shore to shore!
# 9443                                                 NaN
# 13712  He's cool under pressure and sophisticated bet...
# 25202                                                NaN
# 32447                                                NaN
# 6820                                                 NaN
#
#                                          title  video vote_average vote_count
# 33981                          The Genius Club  False          2.5        2.0
# 14572  American Pie Presents: The Book of Love  False          5.1      454.0
# 39804                                 Starship  False          5.5        4.0
# 28016                      My So-Called Father  False          5.5        4.0
# 14249    Abbott and Costello Meet Captain Kidd  False          6.2        7.0
# 9443            The Saddest Music in the World  False          7.9       18.0
# 13712               The Man With Bogart's Face  False          6.0        2.0
# 25202                             Drei Stunden  False          7.5        2.0
# 32447                          Fashion Victims  False          6.6        8.0
# 6820                      The Watermelon Woman  False          8.0        2.0
#
# [10 rows x 24 columns]

# %% [markdown]
# ## II. Train

# %%
from models.contentbased_model import ContentbasedModel

model = ContentbasedModel()
trained_data, movie_data = model.trainingDataBasedOnGenres(metadata_df)

# %%
model.getRecommendataionbasedOnGenres("Toy Story", trained_data, movie_data)

# %%
model.getRecommendationbasedOnOverview("Toy Story", trained_data, movie_data)
